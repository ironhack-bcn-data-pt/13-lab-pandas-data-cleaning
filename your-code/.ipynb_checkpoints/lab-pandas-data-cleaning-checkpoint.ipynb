# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Load data (users.csv, posts.csv)

# %%
users = pd.read_csv('../../13-lab-pandas-data-cleaning/your-code/users.csv')
users
# Out:
#        Unnamed: 0       id     display_name  \
# 0               0   107658       ivordesign
# 1               1   218597           icabod
# 2               2   326360         rbaker86
# 3               3   379556      Rui Marques
# 4               4   450456            Jules
# ...           ...      ...              ...
# 14843       14843   574332  Captain Caveman
# 14844       14844  7155452           Mode-X
# 14845       14845  5529001         V.Savage
# 14846       14846  4105549        Tom Baker
# 14847       14847  4886640         gopisaba
#
#                                                 about_me  age  \
# 0                                                    NaN  NaN
# 1                                                    NaN  NaN
# 2      <p>Software developer and technology enthusias...  NaN
# 3      <p>Engineer and Automation Architect at Vonage...  NaN
# 4                                                    NaN  NaN
# ...

# %%
posts = pd.read_csv('../../13-lab-pandas-data-cleaning/your-code/posts.csv')
posts
# Out:
#               id  owner_user_id  score  view_count  comment_count  \
# 0       30336926            NaN      1          14              3
# 1       36873524            NaN      1          18              0
# 2       36605876            NaN      1          19              0
# 3       36718461            NaN      1          17              0
# 4       30434893            NaN      0          15              0
# ...          ...            ...    ...         ...            ...
# 325605  37142382      6315949.0      0          15              0
# 325606  36884286      3733872.0      0          20              1
# 325607  36140188      5216651.0      0          12              0
# 325608  36293699      4811040.0      1          20              1
# 325609  36028646      5910006.0      0          19              0
#
#         favorite_count
# 0                  NaN
# 1                  1.0
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# ...

# %% [markdown]
# #### 3. Rename id column to user_id

# %%
users.rename(columns={'id':'user_id'},inplace=True)
users
# Out:
#        Unnamed: 0  user_id     display_name  \
# 0               0   107658       ivordesign
# 1               1   218597           icabod
# 2               2   326360         rbaker86
# 3               3   379556      Rui Marques
# 4               4   450456            Jules
# ...           ...      ...              ...
# 14843       14843   574332  Captain Caveman
# 14844       14844  7155452           Mode-X
# 14845       14845  5529001         V.Savage
# 14846       14846  4105549        Tom Baker
# 14847       14847  4886640         gopisaba
#
#                                                 about_me  age  \
# 0                                                    NaN  NaN
# 1                                                    NaN  NaN
# 2      <p>Software developer and technology enthusias...  NaN
# 3      <p>Engineer and Automation Architect at Vonage...  NaN
# 4                                                    NaN  NaN
# ...

# %% [markdown]
# #### 4. Rename id column to post_id and owner_user_id to user_id

# %%
posts.rename(columns={'id':'post_id', 'owner_user_id':'user_id'},inplace=True)
posts
# Out:
#          post_id    user_id  score  view_count  comment_count  favorite_count
# 0       30336926        NaN      1          14              3             NaN
# 1       36873524        NaN      1          18              0             1.0
# 2       36605876        NaN      1          19              0             NaN
# 3       36718461        NaN      1          17              0             NaN
# 4       30434893        NaN      0          15              0             NaN
# ...          ...        ...    ...         ...            ...             ...
# 325605  37142382  6315949.0      0          15              0             1.0
# 325606  36884286  3733872.0      0          20              1             1.0
# 325607  36140188  5216651.0      0          12              0             1.0
# 325608  36293699  4811040.0      1          20              1             1.0
# 325609  36028646  5910006.0      0          19              0             1.0
#
# [325610 rows x 6 columns]

# %% [markdown]
# #### 5. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: user_id, reputation,views,up_votes,down_votes
#     **posts columns**: post_id, score,user_id,view_count,comment_count

# %%
filtered_users = users[['user_id','reputation','views','up_votes','down_votes']]
filtered_users
# Out:
#        user_id  reputation  views  up_votes  down_votes
# 0       107658         305     91         2           0
# 1       218597        6559    374       361          25
# 2       326360        1802     97        40          14
# 3       379556        2335    261       125          10
# 4       450456        7746   3598       256          50
# ...        ...         ...    ...       ...         ...
# 14843   574332          41      6        10           0
# 14844  7155452          41      6         0           0
# 14845  5529001          41     11         0           0
# 14846  4105549          41     11         2           0
# 14847  4886640          41     11        13           0
#
# [14848 rows x 5 columns]

# %%
filtered_posts = posts[['post_id','score','user_id','view_count','comment_count']]
filtered_posts
# Out:
#          post_id  score    user_id  view_count  comment_count
# 0       30336926      1        NaN          14              3
# 1       36873524      1        NaN          18              0
# 2       36605876      1        NaN          19              0
# 3       36718461      1        NaN          17              0
# 4       30434893      0        NaN          15              0
# ...          ...    ...        ...         ...            ...
# 325605  37142382      0  6315949.0          15              0
# 325606  36884286      0  3733872.0          20              1
# 325607  36140188      0  5216651.0          12              0
# 325608  36293699      1  4811040.0          20              1
# 325609  36028646      0  5910006.0          19              0
#
# [325610 rows x 5 columns]

# %% [markdown]
# #### 6. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
filtered_users.dtypes
# Out:
# user_id       int64
# reputation    int64
# views         int64
# up_votes      int64
# down_votes    int64
# dtype: object

# %%
filtered_users.shape
# Out:
# (14848, 5)

# %%
filtered_posts.dtypes
# Out:
# post_id            int64
# score              int64
# user_id          float64
# view_count         int64
# comment_count      int64
# dtype: object

# %%
filtered_posts.shape
# Out:
# (325610, 5)

# %%
# Inner Join > To keep only rows that match from the data frames (Intersection). Default
# Outer Join > To keep all rows from both data frames (Union)

# %%
merged_df = pd.merge(filtered_users, filtered_posts, on='user_id')
merged_df
# Out:
#       user_id  reputation  views  up_votes  down_votes   post_id  score  \
# 0      450456        7746   3598       256          50  34989087      0
# 1      450456        7746   3598       256          50   4142174      0
# 2     1517244        4172    224      1362          32  37211628      2
# 3     1870509         897    105        86           2  30260248      1
# 4      101719        4055    332       174          16  34528617      0
# ...       ...         ...    ...       ...         ...       ...    ...
# 1060  4295902           1      4         0           0  31038301      0
# 1061  2856201          11     21         0           0  19348144      0
# 1062  5882818          11      3         0           0  35199880      0
# 1063  6241297          13      2         0           0  36798683      0
# 1064   592420          21     30         2           0  36739521      0
#
#       view_count  comment_count
# 0             19              0
# 1             15              0
# ...

# %%
# the type of the user_id merge dataframe is int!
merged_df.dtypes
# Out:
# user_id          int64
# reputation       int64
# views            int64
# up_votes         int64
# down_votes       int64
# post_id          int64
# score            int64
# view_count       int64
# comment_count    int64
# dtype: object

# %% [markdown]
# #### 7. How many missing values do you have in your merged dataframe?

# %%
# Inner Join > Intersection between dataframes(Default)

# %%
merged_df.isnull().sum()
# Out:
# user_id          0
# reputation       0
# views            0
# up_votes         0
# down_votes       0
# post_id          0
# score            0
# view_count       0
# comment_count    0
# dtype: int64

# %% [markdown]
# There are no missing values

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder. Hint: post_id cannot have outliers!

# %%
outliers = pd.DataFrame(merged_df)
outliers
# Out:
#       user_id  reputation  views  up_votes  down_votes   post_id  score  \
# 0      450456        7746   3598       256          50  34989087      0
# 1      450456        7746   3598       256          50   4142174      0
# 2     1517244        4172    224      1362          32  37211628      2
# 3     1870509         897    105        86           2  30260248      1
# 4      101719        4055    332       174          16  34528617      0
# ...       ...         ...    ...       ...         ...       ...    ...
# 1060  4295902           1      4         0           0  31038301      0
# 1061  2856201          11     21         0           0  19348144      0
# 1062  5882818          11      3         0           0  35199880      0
# 1063  6241297          13      2         0           0  36798683      0
# 1064   592420          21     30         2           0  36739521      0
#
#       view_count  comment_count
# 0             19              0
# 1             15              0
# ...
